# %%
# import pandas as pd                Import the pasdas library. Alias is pd
# pd.read_csv("path")                Read the .csv file.
# df.shape                           Return the shape of the DataFrame.
# df.head()                          Return the first 5 rows.
# df.tail()                          Return the last 5 rows.
# df.info()                          Return the full information of DataFrame.
# df.to_csv('file name')             Convert the DataFrame into .csv file.
# df.to_excel('file name')           Convert the DataFrame into .excel file.
# df.isnull().sum()                  Return the sum of tatal null values in the DataFrame.
# df.value_counts('column_name')     Return the total values in a particular column.
# df.groupby('column_name').mean()   Return the mean of the each column.
# df.count()                         Retrun the total values in each column.
# df.mean()                          Return the mean of the each column.
# df.std()                           Return the standard_deviation of the each column.
# df.var()                           Return the variance of the each column.
# df.min()                           Return the min value of the each column.
# df.max()                           Return the max value of the each column.
# df.describe()                      It's return all statical values i.e(std,min,max,mean,25%,50%,75%,count).
# df['col_name'] = values            Add a new column in a DataFrame.
# df.drop(index=ind_no , axis=0)     It's drop the particular row from the DataFrame. Row axes is 0.
# df.drop(columns='col_name' , axis=1)   It's drop the particular column from the DataFrame. Col axes is 1.
# df.iloc[0]                         Accessing the first row of the DataFrame.
# df.iloc[ : , 0]                    Accessing the first column of the DataFrame.
# df.corr()          It's return the correlation of the attributes. Which features are dependent each other.
#                    Two types Positive and Negative Correlation.
#                    In Positive corr one value is increases the other is increases.
#                    In Negative corr one value is increases the other is decreases.

# %%
import pandas as pd     # Importing a pandas library.

# %%
print(pd.__version__)     # Return the version of pandas library.
# Out:
# 2.1.1

# %%
dataset = {                               # Creating a dictionary.
    "car" : ['mehran','marcedese','corola'],
    'year' : [2000,2013,2002]
}
df = pd.DataFrame(dataset)              # Dictionary laod into DataFrame.
df                                      # Print the DataFrame.
# Out:
#          car  year
# 0     mehran  2000
# 1  marcedese  2013
# 2     corola  2002

# %%
a = [1,2,4]      # Create a list.
my_var = pd.Series(a)    # It's return a column.
my_var
# Out:
# 0    1
# 1    2
# 2    4
# dtype: int64

# %%
cal = {'day1':123,'day2':432,'day3':234}    # Creating a dictionary.
df = pd.Series(cal)                         # Return a columns
df[0:2]                                     # Print columns 0-1
# Out:
# day1    123
# day2    432
# dtype: int64

# %%
d_f = pd.read_csv('house_pre.csv')       # Load the 'house_pre' data-set into DataFrame.

# %%
d_f     # Print the data-set.
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
d_f.head()         # Return the first 5 rows.
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
pd.options.display.max_rows          # Return the max row printable.
# Out:
# 60

# %%
pd.options.display.min_rows          # Returnthe min row printable.
# Out:
# 10

# %%
d_f.tail()
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# ...

# %%
d_f.info()          # Return the all information about data-set. i.e total_cols, total_row, null_values etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
d_f.shape         # It's return the total rows and columns.
# Out:
# (4600, 18)

# %%
d_f.isnull()    # It's return the null_values.
# Out:
#        date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     False  False     False      False        False     False   False
# 1     False  False     False      False        False     False   False
# 2     False  False     False      False        False     False   False
# 3     False  False     False      False        False     False   False
# 4     False  False     False      False        False     False   False
# ...     ...    ...       ...        ...          ...       ...     ...
# 4595  False  False     False      False        False     False   False
# 4596  False  False     False      False        False     False   False
# 4597  False  False     False      False        False     False   False
# 4598  False  False     False      False        False     False   False
# 4599  False  False     False      False        False     False   False
#
#       waterfront   view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
d_f.isnull().sum()         # It's return the sum of all null_values w.r.t columns.
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
d_f['price']       # It's print the 'price' column.
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
d_f.value_counts('bedrooms')   # It's return the count of each value in bedrooms column.
# Out:
# bedrooms
# 3.0    2032
# 4.0    1531
# 2.0     566
# 5.0     353
# 6.0      61
# 1.0      38
# 7.0      14
# 0.0       2
# 8.0       2
# 9.0       1
# Name: count, dtype: int64

# %%
d_f.groupby('view').sum()      # Firstly groupby view column and sum w.r.t view column.
# Out:
#                                                    date         price  \
# view
# 0     2014-05-02 00:00:002014-05-02 00:00:002014-05-...  2.114236e+09
# 1     2014-05-02 00:00:002014-05-05 00:00:002014-05-...  5.982376e+07
# 2     2014-05-02 00:00:002014-05-02 00:00:002014-05-...  1.658317e+08
# 3     2014-05-05 00:00:002014-05-05 00:00:002014-05-...  1.157921e+08
# 4     2014-05-02 00:00:002014-05-05 00:00:002014-05-...  8.334667e+07
#
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# view
# 0      13945.0    8733.75      8465905  58375652  6247.5           0
# 1        253.0     167.75       184090    746666    96.5           0
# 2        734.0     507.25       572499   4105512   313.0           5
# 3        443.0     319.50       362426   3396716   182.5           5
# 4        269.0     211.50       256076   1697028   116.0          23
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# view
# ...

# %%
d_f['bedrooms'].mean()      # Return the mean value of 'bedrooms' column.
# Out:
# 3.4008695652173913

# %%
d_f['view'].max()          # Return the max value of 'view' column.
# Out:
# 4

# %%
d_f['waterfront'].min()     # Return the min value of 'waterfront' column.
# Out:
# 0

# %%
d_f['view'].std()          # Calculate and return the standard-deviation of 'view' column.
# Out:
# 0.7784047172125442

# %%
d_f['view'].var()          # Calculate and return the variance of 'view' column.
# Out:
# 0.605913903778741

# %%
d_f['view'].count()        # Return the count of 'view' column.
# Out:
# 4600

# %%
d_f.describe()          # Return the all information about the data-set. Example: mean,max,min,25%,50%,75% etc.
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
d_f.drop( index = 2, axis = 0 )      # Drop the row of index 2 and axis=0 use to row
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# 5     2014-05-02 00:00:00  4.900000e+05       2.0       1.00          880
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
d_f.drop(columns = 'date', axis = 1)  # Drop the column 'date' and axis=1 use to column.
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
d_f.loc[0:3]     # Return the particular location. It's locate the row 0-3
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# ...

# %%
d_f.iloc[0:5]       # Locate the row 0-4
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
d_f.iloc[:5,:5]   # Locate the row 0-4 and column 0-4.
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940
